# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
data = pd.DataFrame({
    'X': np.random.rand(100),          
    'Y': 2 * np.random.rand(100) + 0.5  
})

# %%
correlation_coefficient = data['X'].corr(data['Y'])

# %%
sns.scatterplot(data=data)
# Out:
# <AxesSubplot:>

# %%
data.corr().plot()
# Out:
# <AxesSubplot:>
